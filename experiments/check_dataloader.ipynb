# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Samsung\\image-classification-transfer-learning\\experiments'

# %%
os.chdir(r"C:\Users\Samsung\image-classification-transfer-learning")
os.getcwd()
# Out:
# 'C:\\Users\\Samsung\\image-classification-transfer-learning'

# %%
from src.dataset import get_cifar10_loaders

train_loader, val_loader, test_loader = get_cifar10_loaders()

batch = next(iter(train_loader))
images, labels = batch
images.shape, labels.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.dataset import get_cifar10_loaders
#       3 train_loader, val_loader, test_loader = get_cifar10_loaders()
#       5 batch = next(iter(train_loader))
#
# ModuleNotFoundError: No module named 'src'
